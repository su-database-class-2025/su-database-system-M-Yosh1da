# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# 埼玉県の交番を抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.amenity ='police' and
    poly.name_1='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#           osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0     1420167828   None           None             None               None
# 1    11018646179   None           None             None               None
# 2    11836842777   None           None             None               None
# 3     1420167845   None           None             None               None
# 4     1420190220   None           None             None               None
# ..           ...    ...            ...              ...                ...
# 363   1420171086   None           None             None               None
# 364   1420191447   None           None             None               None
# 365   1420169678   None           None             None               None
# 366   1420197879   None           None             None               None
# 367   1420179656   None           None             None               None
#
#     admin_level aerialway aeroway amenity  area barrier bicycle brand bridge  \
# 0          None      None    None  police  None    None    None  None   None
# 1          None      None    None  police  None    None    None  None   None
# 2          None      None    None  police  None    None    None  None   None
# 3          None      None    None  police  None    None    None  None   None
# 4          None      None    None  police  None    None    None  None   None
# ..          ...       ...     ...     ...   ...     ...     ...   ...    ...
# 363        None      None    None  police  None    None    None  None   None
# 364        None      None    None  police  None    None    None  None   None
# 365        None      None    None  police  None    None    None  None   None
# 366        None      None    None  police  None    None    None  None   None
# 367        None      None    None  police  None    None    None  None   None
#
#     boundary building capital construction covered culvert cutting  \
# 0       None     None    None         None    None    None    None
# 1       None     None    None         None    None    None    None
# 2       None     None    None         None    None    None    None
# 3       None     None    None         None    None    None    None
# 4       None     None    None         None    None    None    None
# ..       ...      ...     ...          ...     ...     ...     ...
# 363     None     None    None         None    None    None    None
# 364     None     None    None         None    None    None    None
# 365     None     None    None         None    None    None    None
# 366     None     None    None         None    None    None    None
# 367     None     None    None         None    None    None    None
#
#     denomination disused   ele embankment  foot generator:source harbour  \
# 0           None    None  None       None  None             None    None
# 1           None    None  None       None  None             None    None
# 2           None    None  None       None  None             None    None
# 3           None    None  None       None  None             None    None
# 4           None    None  None       None  None             None    None
# ..           ...     ...   ...        ...   ...              ...     ...
# 363         None    None  None       None  None             None    None
# 364         None    None  None       None  None             None    None
# 365         None    None  None       None  None             None    None
# 366         None    None  None       None  None             None    None
# 367         None    None  None       None  None             None    None
#
#     highway historic horse intermittent junction landuse layer leisure  lock  \
# 0      None     None  None         None     None    None  None    None  None
# 1      None     None  None         None     None    None  None    None  None
# 2      None     None  None         None     None    None  None    None  None
# 3      None     None  None         None     None    None  None    None  None
# 4      None     None  None         None     None    None  None    None  None
# ..      ...      ...   ...          ...      ...     ...   ...     ...   ...
# 363    None     None  None         None     None    None  None    None  None
# 364    None     None  None         None     None    None  None    None  None
# 365    None     None  None         None     None    None  None    None  None
# 366    None     None  None         None     None    None  None    None  None
# 367    None     None  None         None     None    None  None    None  None
#
#     man_made military motorcar          name natural office oneway operator  \
# 0       None     None     None     上尾警察署平方交番    None   None   None     None
# 1       None     None     None    上尾市上平防犯連絡所    None   None   None     None
# 2       None     None     None         上尾警察署    None   None   None     None
# 3       None     None     None    上尾警察署西上尾交番    None   None   None     None
# 4       None     None     None  上尾警察署上尾駅東口交番    None   None   None     None
# ..       ...      ...      ...           ...     ...    ...    ...      ...
# 363     None     None     None    寄居警察署用土駐在所    None   None   None     None
# 364     None     None     None   吉川警察署吉川駅前交番    None   None   None     None
# 365     None     None     None     吉川警察署吉川交番    None   None   None     None
# 366     None     None     None    東松山警察署吉見交番    None   None   None     None
# 367     None     None     None  東松山警察署吉見東駐在所    None   None   None     None
#
#     place   poi population power power_source public_transport railway   ref  \
# 0    None  None       None  None         None             None    None  None
# 1    None  None       None  None         None             None    None  None
# 2    None  None       None  None         None             None    None  None
# 3    None  None       None  None         None             None    None  None
# 4    None  None       None  None         None             None    None  None
# ..    ...   ...        ...   ...          ...              ...     ...   ...
# 363  None  None       None  None         None             None    None  None
# 364  None  None       None  None         None             None    None  None
# 365  None  None       None  None         None             None    None  None
# 366  None  None       None  None         None             None    None  None
# 367  None  None       None  None         None             None    None  None
#
#     religion route service  shop sport surface  toll tourism tower:type  \
# 0       None  None    None  None  None    None  None    None       None
# 1       None  None    None  None  None    None  None    None       None
# 2       None  None    None  None  None    None  None    None       None
# 3       None  None    None  None  None    None  None    None       None
# 4       None  None    None  None  None    None  None    None       None
# ..       ...   ...     ...   ...   ...     ...   ...     ...        ...
# 363     None  None    None  None  None    None  None    None       None
# 364     None  None    None  None  None    None  None    None       None
# 365     None  None    None  None  None    None  None    None       None
# 366     None  None    None  None  None    None  None    None       None
# 367     None  None    None  None  None    None  None    None       None
#
#     tunnel water waterway wetland width  wood z_order  \
# 0     None  None     None    None  None  None    None
# 1     None  None     None    None  None  None    None
# 2     None  None     None    None  None  None    None
# 3     None  None     None    None  None  None    None
# 4     None  None     None    None  None  None    None
# ..     ...   ...      ...     ...   ...   ...     ...
# 363   None  None     None    None  None  None    None
# 364   None  None     None    None  None  None    None
# 365   None  None     None    None  None  None    None
# 366   None  None     None    None  None  None    None
# 367   None  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15535931.924 4293695.004)
# 1    POINT (15538968.007 4300069.451)
# 2    POINT (15539108.982 4297907.884)
# 3    POINT (15536058.483 4295717.288)
# 4    POINT (15538985.918 4296925.309)
# ..                                ...
# 363  POINT (15495938.281 4321280.405)
# 364  POINT (15567305.207 4283624.412)
# 365   POINT (15567095.67 4284884.222)
# 366  POINT (15523844.742 4307812.614)
# 367  POINT (15525061.909 4305987.525)
#
# [368 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f1a94a6deb9fe44e1d264dec1d26ac1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f1a94a6deb9fe44e1d264dec1d26ac1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f1a94a6deb9fe44e1d264dec1d26ac1 = L.map(
#                 &quot;map_0f1a94a6deb9fe44e1d264dec1d26ac1&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b41b0f8058e9359b4c6bb682283266a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b41b0f8058e9359b4c6bb682283266a4.addTo(map_0f1a94a6deb9fe44e1d264dec1d26ac1);
#
#
#             var marker_98dd80ca51f9ae1e29fe45b764844934 = L.marker(
#                 [35.94964639973057, 139.561651],
#                 {
# }
#             ).addTo(map_0f1a94a6deb9fe44e1d264dec1d26ac1);
#
#
#         var popup_43b36f88ba03442748894d463d785f77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fa357d56b4302c5b13cc0041e93658f = $(`&lt;div id=&quot;html_4fa357d56b4302c5b13cc0041e93658f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;上尾警察署平方交番&lt;/div&gt;`)[0];
#                 popup_43b36f88ba03442748894d463d785f77.setContent(html_4fa357d56b4302c5b13cc0041e93658f);
#
#
#
#         marker_98dd80ca51f9ae1e29fe45b764844934.bindPopup(popup_43b36f88ba03442748894d463d785f77)
#         ;
#
#
#
#
#             var marker_b45f53218e0b336f3b3b5eb4e606e282 = L.marker(
#                 [35.99598879973514, 139.5889246],
#                 {
# }
#             ).addTo(map_0f1a94a6deb9fe44e1d264dec1d26ac1);
#
#
#         var popup_15bad76f633c07a6d0f8122c8943bdc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_275fcf6a5aca57e1676f978b5e6e23f1 = $(`&lt;div id=&quot;html_275fcf6a5aca57e1676f978b5e6e23f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;上尾市上平防犯連絡所&lt;/div&gt;`)[0];
#                 popup_15bad76f633c07a6d0f8122c8943bdc9.setContent(html_275fcf6a5aca57e1676f978b5e6e23f1);
#
#
#
#         marker_b45f53218e0b336f3b3b5eb4e606e282.bindPopup(popup_15bad76f633c07a6d0f8122c8943bdc9)
#         ;
#
#
#
#
#             var marker_e7a5ff19e29db7b141488406de0dad59 = L.marker(
#                 [35.980277199733585, 139.590191],
#                 {
# }
#             ).addTo(map_0f1a94a6deb9fe44e1d264dec1d26ac1);
#
#
#         var popup_e3301835c19bb8aa359095163ceb32b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcf0116b32b4a8b0721b41cfc234e7de = $(`&lt;div id=&quot;html_dcf0116b32b4a8b0721b41cfc234e7de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;上尾警察署&lt;/div&gt;`)[0];
#                 popup_e3301835c19bb8aa359095163ceb32b0.setContent(html_dcf0116b32b4a8b0721b41cfc234e7de);
#
#
#
#         marker_e7a5ff19e29db7b141488406de0dad59.bindPopup(popup_e3301835c19bb8aa359095163ceb32b0)
#         ;
#
#
#
#
#             var marker_78f005352bf9a47db5cb63af4fd5c951 = L.marker(
#                 [35.96435139973202, 139.56278790000002],
#                 {
# }
#             ).addTo(map_0f1a94a6deb9fe44e1d264dec1d26ac1);
#
#
#         var popup_ca4c323e6e75036dffb3b7e6ec57748f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e43b87e6ad65c8b697dcf09425d42ba4 = $(`&lt;div id=&quot;html_e43b87e6ad65c8b697dcf09425d42ba4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;上尾警察署西上尾交番&lt;/div&gt;`)[0];
#                 popup_ca4c323e6e75036dffb3b7e6ec57748f.setContent(html_e43b87e6ad65c8b697dcf09425d42ba4);
#
#
#
#         marker_78f005352bf9a47db5cb63af4fd5c951.bindPopup(popup_ca4c323e6e75036dffb3b7e6ec57748f)
#         ;
#
#
#
#
#             var marker_3f09952ea260ba3d33c915865ce49a76 = L.marker(
#                 [35.973134199732876, 139.58908549999998],
#                 {
# }
#             ).addTo(map_0f1a94a6deb9fe44e1d264dec1d26ac1);
#
#
#         var popup_bcb7f45019cfcd99ff038095dfb2adad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6117f7786a5f9f73ca53332186fc09a = $(`&lt;div id=&quot;html_e6117f7786a5f9f73ca53332186fc09a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;上尾警察署上尾駅東口交番&lt;/div&gt;`)[0];
#                 popup_bcb7f45019cfcd99ff038095dfb2adad.setContent(html_e6117f7786a5f9f73ca53332186fc09a);
#
#
#
#         marker_3f09952ea260ba3d33c915865ce49a76.bindPopup(popup_bcb7f45019cfcd99ff038095dfb2adad)
#         ;
#
#
#
#
#             var marker_615de7c55dafcbd7ae5885bd3056d7ee = L.marker(
